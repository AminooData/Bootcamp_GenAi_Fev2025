# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Charger les données depuis le fichier CSV
df = pd.read_csv('2019.csv')
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
print(df.isnull().sum())
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))  # Définir la taille de la figure
plt.scatter(df['Social support'], df['Score'], color='blue', alpha=0.5)
plt.title('Relation entre le soutien social et le score de bonheur')
plt.xlabel('Soutien social')
plt.ylabel('Score de bonheur')
plt.grid(True)
plt.show()

# %%
print(df.columns.tolist())
df.rename(columns={'Country or region': 'Region'}, inplace=True)
print(df['Region'])
# Out:
# ['Overall rank', 'Region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']
# 0                       Finland
# 1                       Denmark
# 2                        Norway
# 3                       Iceland
# 4                   Netherlands
#                  ...
# 151                      Rwanda
# 152                    Tanzania
# 153                 Afghanistan
# 154    Central African Republic
# 155                 South Sudan
# Name: Region, Length: 156, dtype: object

# %%
# Définir la taille de la figure
fig, ax1 = plt.subplots(figsize=(12, 8))

# Tracer le diagramme à barres pour le PIB par habitant
bar_width = 0.4
bar_positions = range(len(df['Region']))
bars = ax1.bar(bar_positions, df['GDP per capita'], bar_width, align='center', color='skyblue', label='PIB par habitant')

# Configuration de l'axe des ordonnées pour le PIB
ax1.set_xlabel('Région')
ax1.set_ylabel('PIB par habitant (€)', color='blue')
ax1.set_xticks(bar_positions)
ax1.set_xticklabels(df['Region'], rotation=45, ha='right')
ax1.tick_params(axis='y', labelcolor='blue')

# Création d'un second axe des ordonnées pour l'espérance de vie
ax2 = ax1.twinx()
ax2.plot(bar_positions, df['Healthy life expectancy'], color='green', marker='o', label='Espérance de vie en bonne santé')
ax2.set_ylabel('Espérance de vie en bonne santé (années)', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Ajouter une légende
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))

# Ajouter un titre
plt.title('Comparaison du PIB par habitant et de l\'espérance de vie en bonne santé par région')

# Ajuster la mise en page pour éviter le chevauchement
fig.tight_layout()

# Afficher le graphique
plt.show()
